# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system
    
    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates if a bucket name follows AWS S3 naming conventions.\n    \n    AWS S3 bucket naming rules:\n    - Must be between 3 and 63 characters long\n    - Can only contain lowercase letters, numbers, hyphens, and periods\n    - Must start and end with a letter or number\n    - Cannot contain underscores\n    - Cannot be formatted as an IP address (e.g., 192.168.1.1)\n    \n    Args:\n        bucket_name: The S3 bucket name to validate\n        \n    Returns:\n        True if the bucket name is valid, False otherwise\n    \"\"\"\n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Check for valid characters (lowercase letters, numbers, hyphens, periods)\n    # and that it starts and ends with a letter or number\n    pattern = r'^[a-z0-9]([a-z0-9\\-\\.]*[a-z0-9])?$'\n    if not re.match(pattern, bucket_name):\n        return False\n    \n    # Check that it's not formatted as an IP address\n    if re.match(r'^(\\d+\\.){3}\\d+$', bucket_name):\n        return False\n    \n    # Check for consecutive hyphens or periods (not allowed in some cases)\n    if '..' in bucket_name or '--' in bucket_name:\n        return False\n    \n    return True\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid bucket names\n        (\"my-bucket\", True),\n        (\"bucket123\", True),\n        (\"a\", False),  # Too short\n        (\"ab\", False),  # Too short\n        (\"abc\", True),  # Minimum valid length\n        (\"my-bucket-123\", True),\n        (\"bucket.name\", True),\n        (\"a1b2c3\", True),\n        \n        # Invalid bucket names\n        (\"My-Bucket\", False),  # Contains uppercase\n        (\"my_bucket\", False),  # Contains underscore\n        (\"my bucket\", False),  # Contains space\n        (\"my-bucket-\", False),  # Ends with hyphen\n        (\"-my-bucket\", False),  # Starts with hyphen\n        (\"a\" * 64, False),  # Too long (64 characters)\n        (\"192.168.1.1\", False),  # Formatted as IP address\n        (\"my..bucket\", False),  # Consecutive periods\n        (\"my--bucket\", False),  # Consecutive hyphens\n        (\"\", False),  # Empty string\n        (\"my-bucket!\", False),  # Invalid character\n        (123, False),  # Not a string\n        (None, False),  # Not a string\n    ]\n    \n    print(\"S3 Bucket Name Validation Tests:\\n\")\n    for bucket_name, expected in test_cases:\n        result = is_valid_s3_bucket_name(bucket_name)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} '{bucket_name}' -> {result} (expected {expected})\")\n```\n\n## Output:\n```\nS3 Bucket Name Validation Tests:\n\n\u2713 'my-bucket' -> True (expected True)\n\u2713 'bucket123' -> True (expected True)\n\u2713 'a' -> False (expected False)\n\u2713 'ab' -> False (expected False)\n\u2713 'abc' -> True (expected True)\n\u2713 'my-bucket-123' -> True (expected True)\n\u2713 'bucket.name' -> True (expected True)\n\u2713 'a1b2c3' -> True (expected True)\n\u2713 'My-Bucket' -> False (expected False)",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and returns True if it follows AWS naming conventions (lowercase, 3-63 characters, no underscores), False otherwise."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Policy for S3 GetObject and PutObject\n\nHere's a JSON object that represents an AWS IAM policy allowing GetObject and PutObject actions on a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3GetPutObjectAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    }\n  ]\n}\n```\n\n## Explanation:\n\n- **Version**: Standard IAM policy language version (always \"2012-10-17\")\n- **Statement**: Array containing policy rules\n- **Sid**: Optional identifier for the statement (helpful for documentation)\n- **Effect**: \"Allow\" grants the specified permissions\n- **Action**: Array of allowed S3 actions:\n  - `s3:GetObject` - Read/download objects from the bucket\n  - `s3:PutObject` - Upload/write objects to the bucket\n- **Resource**: The S3 bucket ARN with `/*` to apply to all objects in the bucket\n  - Replace `my-bucket-name` with your actual bucket name\n\n## Alternative: If you need to allow bucket-level operations too:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3GetPutObjectAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucketAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": \"s3:ListBucket\",\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\"\n    }\n  ]\n}\n```\n\nThis second version also includes ListBucket permission, which is often needed to list objects in the bucket.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing a principal to perform GetObject and PutObject actions on a specific S3 bucket ARN."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's a regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{8}$|^i-[0-9a-f]{17}$\n```\n\nOr more concisely:\n\n```regex\n^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$\n```\n\nOr as a single character class range:\n\n```regex\n^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$\n```\n\n## Explanation\n\n- `^` - Start of string\n- `i-` - Literal \"i-\" prefix\n- `[0-9a-f]{8}` - Exactly 8 hexadecimal characters (0-9, a-f)\n- `(?:[0-9a-f]{9})?` - Optionally followed by 9 more hexadecimal characters (making it 17 total)\n- `$` - End of string\n\n## Examples\n\n```\n\u2713 i-0a1b2c3d        (8 hex chars)\n\u2713 i-0a1b2c3d9e8f7g6 (17 hex chars) - Wait, 'g' is invalid\n\u2713 i-0a1b2c3d9e8f7a6 (17 hex chars - corrected)\n\u2717 i-0a1b2c          (too short)\n\u2717 i-0a1b2c3d9e8f7a6e (too long)\n```\n\n## Language-Specific Examples\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$'\nre.match(pattern, 'i-0a1b2c3d')\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$/;\npattern.test('i-0a1b2c3d');\n```\n\n**Note:** AWS EC2 instance IDs are typically lowercase, but you may want to add case-insensitivity with the `i` flag if needed: `/^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$/i`",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i-followed by 8 or 17 hexadecimal characters)."
#     },
#     "score": 10
#   }
# ]
