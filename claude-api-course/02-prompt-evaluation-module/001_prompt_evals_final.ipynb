# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nfrom typing import Dict, Any, Optional\n\ndef parse_cloudtrail_log(log_entry: str) -> Dict[str, Any]:\n    \"\"\"Parse AWS CloudTrail log entry and extract event name, principal ID, and timestamp.\"\"\"\n    try:\n        log_data = json.loads(log_entry)\n        return {\n            \"eventName\": log_data.get(\"eventName\"),\n            \"principalId\": log_data.get(\"userIdentity\", {}).get(\"principalId\"),\n            \"timestamp\": log_data.get(\"eventTime\")\n        }\n    except json.JSONDecodeError:\n        return None\n\ndef parse_cloudtrail_regex(log_entry: str) -> Optional[Dict[str, str]]:\n    \"\"\"Parse using regex as alternative approach.\"\"\"\n    event_match = re.search(r'\"eventName\"\\s*:\\s*\"([^\"]*)\"', log_entry)\n    principal_match = re.search(r'\"principalId\"\\s*:\\s*\"([^\"]*)\"', log_entry)\n    timestamp_match = re.search(r'\"eventTime\"\\s*:\\s*\"([^\"]*)\"', log_entry)\n    \n    if event_match and principal_match and timestamp_match:\n        return {\n            \"eventName\": event_match.group(1),\n            \"principalId\": principal_match.group(1),\n            \"timestamp\": timestamp_match.group(1)\n        }\n    return None\n\n\nsample_log = '''{\"eventVersion\":\"1.05\",\"userIdentity\":{\"type\":\"IAMUser\",\"principalId\":\"AIDACKCEVSQ6C2EXAMPLE\",\"arn\":\"arn:aws:iam::123456789012:user/Alice\",\"accountId\":\"123456789012\",\"invokedBy\":\"cloudformation.amazonaws.com\",\"userName\":\"Alice\"},\"eventTime\":\"2021-05-06T17:08:05Z\",\"eventSource\":\"ec2.amazonaws.com\",\"eventName\":\"StartInstances\",\"awsRegion\":\"us-east-1\",\"sourceIPAddress\":\"192.0.2.1\",\"userAgent\":\"aws-cli/2.1.34\",\"requestParameters\":{\"instancesSet\":{\"items\":[{\"instanceId\":\"i-1234567890abcdef0\"}]}},\"responseElements\":null,\"requestId\":\"12345678-1234-1234-1234-123456789012\",\"eventID\":\"1\",\"eventType\":\"AwsApiCall\",\"eventCategory\":\"Management\",\"recipientAccountId\":\"123456789012\"}'''\n\nresult = parse_cloudtrail_log(sample_log)\nprint(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudTrail log entry and extract the event name, principal ID, and timestamp in a structured format",
#       "format": "json",
#       "solution_criteria": "Output should be a valid JSON object with keys for eventName, principalId, and eventTime that correctly maps to CloudTrail log fields"
#     },
#     "score": 3.5,
#     "reasoning": "The solution correctly parses CloudTrail logs and extracts the required fields from proper nested paths (principalId from userIdentity object). However, it fails the stated criteria in two ways: (1) the output uses 'timestamp' instead of 'eventTime' as the key name, and (2) error handling returns None instead of a valid JSON object. The regex fallback adds unnecessary complexity and maintenance burden without clear justification. The core logic is sound but needs minor adjustments to fully meet requirements."
#   },
#   {
#     "output": "\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name):\n    pattern = r'^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$'\n    return bool(re.match(pattern, bucket_name)) and 3 <= len(bucket_name) <= 63\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and returns True if it follows AWS naming conventions (lowercase, hyphens allowed, 3-63 characters), False otherwise",
#       "format": "python",
#       "solution_criteria": "Function should validate bucket name against AWS rules and handle edge cases like consecutive hyphens and leading/trailing hyphens correctly"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly handles most AWS S3 naming requirements: enforces 3-63 character length, requires lowercase alphanumeric characters with hyphens, and prevents leading/trailing hyphens. However, it has a critical flaw: AWS explicitly prohibits consecutive hyphens (e.g., 'my--bucket' is invalid), but this regex pattern would accept them since the middle section [a-z0-9-]{1,61} allows consecutive hyphens. Additionally, the function lacks defensive programming for invalid input types. The regex pattern itself is well-constructed for the constraints it does enforce."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-_/\\.]+$\n",
#     "test_case": {
#       "task": "Create a regular expression that matches valid AWS IAM role ARNs in the format arn:aws:iam::123456789012:role/RoleName",
#       "format": "regex",
#       "solution_criteria": "Regex should match valid IAM role ARNs, capture the account ID and role name, and reject invalid formats like missing account ID or invalid characters"
#     },
#     "score": 7.5,
#     "reasoning": "The regex successfully validates the basic ARN format and structure, correctly enforcing the 12-digit account ID. However, it fails to meet the explicit requirement of capturing the account ID and role name, instead only performing pattern matching. Additionally, the role name character class is overly permissive and doesn't align with AWS IAM naming constraints, which typically restrict consecutive slashes and leading/trailing special characters. The solution would benefit from capture groups and stricter role name validation."
#   }
# ]
