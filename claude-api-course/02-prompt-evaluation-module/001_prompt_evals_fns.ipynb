# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\nfrom typing import Dict, Optional\n\ndef parse_s3_uri(uri: str) -> Optional[Dict[str, str]]:\n    \"\"\"Parse an AWS S3 bucket URI and extract bucket name and object key.\"\"\"\n    \n    patterns = [\n        # s3://bucket/key\n        r'^s3://(?P<bucket>[a-z0-9.-]+)/(?P<key>.+)$',\n        # s3://bucket (no key)\n        r'^s3://(?P<bucket>[a-z0-9.-]+)/?$',\n        # https://s3.amazonaws.com/bucket/key\n        r'^https://s3\\.amazonaws\\.com/(?P<bucket>[a-z0-9.-]+)/(?P<key>.+)$',\n        # https://bucket.s3.amazonaws.com/key\n        r'^https://(?P<bucket>[a-z0-9.-]+)\\.s3\\.amazonaws\\.com/(?P<key>.+)$',\n        # https://s3.region.amazonaws.com/bucket/key\n        r'^https://s3[.-](?P<region>[a-z0-9-]+)\\.amazonaws\\.com/(?P<bucket>[a-z0-9.-]+)/(?P<key>.+)$',\n        # https://bucket.s3.region.amazonaws.com/key\n        r'^https://(?P<bucket>[a-z0-9.-]+)\\.s3[.-](?P<region>[a-z0-9-]+)\\.amazonaws\\.com/(?P<key>.+)$',\n    ]\n    \n    for pattern in patterns:\n        match = re.match(pattern, uri, re.IGNORECASE)\n        if match:\n            groups = match.groupdict()\n            return {\n                \"bucket\": groups.get(\"bucket\"),\n                \"key\": groups.get(\"key\", \"\")\n            }\n    \n    return None\n\n\nif __name__ == \"__main__\":\n    test_uris = [\n        \"s3://my-bucket/path/to/object.txt\",\n        \"s3://my-bucket\",\n        \"https://s3.amazonaws.com/my-bucket/path/to/object.txt\",\n        \"https://my-bucket.s3.amazonaws.com/path/to/object.txt\",\n        \"https://s3.us-west-2.amazonaws.com/my-bucket/path/to/object.txt\",\n        \"https://my-bucket.s3.us-west-2.amazonaws.com/path/to/object.txt\",\n    ]\n    \n    for uri in test_uris:\n        result = parse_s3_uri(uri)\n        print(json.dumps({\"uri\": uri, \"parsed\": result}, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket URI and extract the bucket name and object key",
#       "format": "regex"
#     },
#     "score": 3.5,
#     "reasoning": "The solution effectively addresses the core task with solid pattern matching for common S3 URI formats. The code is clean and handles the happy path well. However, the bucket name validation is overly restrictive (rejects uppercase despite re.IGNORECASE flag), lacks full AWS S3 naming rule validation, and doesn't handle several valid S3 URI formats like access points or URLs with query parameters. These are important edge cases in production AWS environments. The solution is good for basic use cases but would benefit from stricter validation and broader format support."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"ProcessS3Events\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-s3-execution-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 300,\n  \"MemorySize\": 128,\n  \"Environment\": {\n    \"Variables\": {\n      \"S3_BUCKET\": \"my-bucket\"\n    }\n  },\n  \"EventInvokeConfig\": {\n    \"MaximumEventAge\": 3600,\n    \"MaximumRetryAttempts\": 2,\n    \"DestinationConfig\": {\n      \"OnFailure\": {\n        \"Type\": \"SQS\",\n        \"Destination\": \"arn:aws:sqs:us-east-1:ACCOUNT_ID:failure-queue\"\n      }\n    }\n  },\n  \"Code\": {\n    \"ZipFile\": \"UEsDBAoAAAAAAId+...\",\n    \"S3Bucket\": \"lambda-code-bucket\",\n    \"S3Key\": \"function.zip\"\n  },\n  \"Layers\": [],\n  \"VpcConfig\": {\n    \"SubnetIds\": [],\n    \"SecurityGroupIds\": []\n  },\n  \"Architectures\": [\n    \"x86_64\"\n  ],\n  \"EphemeralStorage\": {\n    \"Size\": 512\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events with a 5-minute timeout",
#       "format": "json"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly addresses the core requirement (5-minute timeout at 300 seconds) and includes good practices like error handling and environment variables. However, it has a structural flaw with conflicting Code specifications and lacks the S3 event source mapping that would enable S3 events to actually trigger the function. The solution defines a Lambda function configuration but is incomplete for the stated use case of processing S3 events."
#   },
#   {
#     "output": "\nimport re\n\ndef is_valid_iam_role_arn(arn: str) -> bool:\n    pattern = r'^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$'\n    return bool(re.match(pattern, arn))\n\n# Test cases\ntest_cases = [\n    (\"arn:aws:iam::123456789012:role/MyRole\", True),\n    (\"arn:aws:iam::123456789012:role/service-role/MyRole\", True),\n    (\"arn:aws:iam::123456789012:role/MyRole-123_test\", True),\n    (\"arn:aws:iam::123456789012:user/MyUser\", False),\n    (\"arn:aws:iam::invalid:role/MyRole\", False),\n    (\"arn:aws:s3:::my-bucket\", False),\n    (\"arn:aws:iam::123456789012:role/\", False),\n    (\"invalid-arn\", False),\n    (\"\", False),\n]\n\nfor test_arn, expected in test_cases:\n    result = is_valid_iam_role_arn(test_arn)\n    print(f\"{test_arn}: {result} (expected {expected})\")\n",
#     "test_case": {
#       "task": "Write a Python function that validates if a given string is a valid AWS IAM role ARN",
#       "format": "python"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements basic IAM role ARN validation and passes all provided test cases. The regex pattern is appropriate for most use cases and the code is maintainable. However, it lacks comprehensive validation of AWS-specific constraints like role name length limits and doesn't fully document whether nested paths are intentionally supported. For production use, especially in security-sensitive contexts, additional validation against official AWS ARN specifications would strengthen the implementation."
#   }
# ]
