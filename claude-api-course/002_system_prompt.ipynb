# %%
# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (0.101.0)
# Requirement already satisfied: python-dotenv in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/stuartbarber/Library/Python/3.13/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's question.
Guide them to a solution step by step.
"""

add_user_message(messages, "How do I solve 5x+3=2 for x?")

answer = chat(messages, system=system)

answer
# Out:
# /var/folders/q2/5hyjyrnn6cq5ly8vyrflsjm80000gn/T/ipykernel_24900/3624286078.py:19: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(**params)
# 'I\'ll help you work through this step by step! When solving an equation like 5x + 3 = 2, our goal is to isolate x (get x by itself on one side).\n\nLet\'s start with the first step. Looking at the left side of the equation, what do you think we should do to begin isolating x? \n\nWhat operation could we perform to both sides of the equation to eliminate the "+3" on the left side?'
